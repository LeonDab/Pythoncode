# %%
#Import Libraries

import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from databento import DBNStore
import mplfinance as mpf
import numpy as np
np.NaN = np.nan
import pandas_ta as ta
import vectorbt as vbt
import matplotlib.lines as mlines
import matplotlib.patches as mpatches

# %%
#Import Data (1m OHLCV)

base = Path("/Users/leondabrowski/Downloads/XNAS-20250808-4WWGNNXWUF/")
dbn_file = base / "xnas-itch-20240808-20250807.ohlcv-1m.dbn.zst"

store = DBNStore.from_file(path=str(dbn_file))
df = store.to_df()  

df.index = pd.to_datetime(df.index)
df = df.sort_index()

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print(df.head())
df.describe()
# Out:
# Shape: (189309, 9)
# Columns: ['rtype', 'publisher_id', 'instrument_id', 'open', 'high', 'low', 'close', 'volume', 'symbol']
#                            rtype  publisher_id  instrument_id    open    high  \
# ts_event
# 2024-08-08 08:00:00+00:00     33             2          15144  516.61  516.77
# 2024-08-08 08:01:00+00:00     33             2          15144  516.60  516.80
# 2024-08-08 08:02:00+00:00     33             2          15144  516.83  517.23
# 2024-08-08 08:03:00+00:00     33             2          15144  517.15  517.22
# 2024-08-08 08:04:00+00:00     33             2          15144  517.18  517.18
#
#                               low   close  volume symbol
# ts_event
# 2024-08-08 08:00:00+00:00  516.57  516.71     238    SPY
# 2024-08-08 08:01:00+00:00  516.60  516.75     160    SPY
# 2024-08-08 08:02:00+00:00  516.77  517.23     216    SPY
# 2024-08-08 08:03:00+00:00  517.15  517.22     483    SPY
# 2024-08-08 08:04:00+00:00  517.18  517.18      13    SPY
#           rtype  publisher_id  instrument_id           open           high  \
# count  189309.0      189309.0       189309.0  189309.000000  189309.000000
# mean       33.0           2.0        15144.0     582.906444     583.001033
# std         0.0           0.0            0.0      27.916114      27.877579
# min        33.0           2.0        15144.0     482.630000     483.160000
# 25%        33.0           2.0        15144.0     563.020000     563.110000
# 50%        33.0           2.0        15144.0     586.620000     586.700000
# 75%        33.0           2.0        15144.0     601.910000     602.020000
# max        33.0           2.0        15144.0     641.440000     641.440000
#
#                  low          close        volume
# count  189309.000000  189309.000000  1.893090e+05
# mean      582.808862     582.906501  1.107763e+04
# std        27.954410      27.915735  2.416762e+04
# min       481.800000     482.660000  1.000000e+00
# 25%       562.940000     563.020000  3.050000e+02
# 50%       586.520000     586.610000  4.616000e+03
# 75%       601.820000     601.910000  1.361800e+04
# max       641.440000     641.440000  1.693443e+06

# %%
#Reformat df to 4h

df = df.reset_index()
df['ts_event'] = pd.to_datetime(df['ts_event'])
df = df.set_index('ts_event').sort_index()

df = df.resample('4h', label='right', closed='right').agg({
    'open':  'first',
    'high':  'max',
    'low':   'min',
    'close': 'last',
    'volume':'sum'}).dropna()

print(df.head())
print(df.index.name)
df.info()
# Out:
#                              open    high     low   close   volume
# ts_event
# 2024-08-08 08:00:00+00:00  516.61  516.77  516.57  516.71      238
# 2024-08-08 12:00:00+00:00  516.60  519.33  516.35  519.19   123452
# 2024-08-08 16:00:00+00:00  519.19  528.48  518.43  527.69  4764144
# 2024-08-08 20:00:00+00:00  527.66  531.82  526.65  531.77  5582640
# 2024-08-09 00:00:00+00:00  531.79  532.07  530.45  531.58   485993
# ts_event
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1158 entries, 2024-08-08 08:00:00+00:00 to 2025-08-08 00:00:00+00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    1158 non-null   float64
#  1   high    1158 non-null   float64
#  2   low     1158 non-null   float64
#  3   close   1158 non-null   float64
#  4   volume  1158 non-null   uint64
# dtypes: float64(4), uint64(1)
# memory usage: 54.3 KB

# %%
#Visualise the data

df.index = pd.to_datetime(df.index)

mpf.plot(
    df,
    type='candle',              
    style='yahoo',              
    title="4h Candles — SPY",
    ylabel="Price",
    volume=True,                
    figratio=(12, 6),
    datetime_format='%Y-%m-%d %H:%M',
    tight_layout=True
    )

#Zoomed in one for 10 days to check if candlesticks are as expected

df_last10 = df[df.index >= df.index.max() - pd.Timedelta(days=10)]
mpf.plot(df_last10, type='candle', style='yahoo', volume=True, figratio=(12, 6))
# Out:
# /Users/leondabrowski/Quanty Coding stuff/quantystuff/lib/python3.12/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
#
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================

# %%
#Parameters and settings for strategy

std = 2.0         
sl = 20          
initial_equity = 100000
no_of_shares = 100

#Makes sure timezone is EST

px = df.copy()
px.index = (px.index.tz_localize("UTC") if px.index.tz is None else px.index).tz_convert("US/Eastern")

#Anchors pandas_ta to days

px_naive = px.copy()
px_naive.index = px_naive.index.tz_localize(None)

vwap_naive = ta.vwap(
    high=px_naive["high"], low=px_naive["low"], close=px_naive["close"], volume=px_naive["volume"],
    anchor="D"
).rename("vwap")

sess_naive = pd.Series(px_naive.index.date, index=px_naive.index, name="session")
exp_std_naive = (
    px_naive["close"].groupby(sess_naive).expanding().std().reset_index(level=0, drop=True)
)

upper_naive = (vwap_naive + std * exp_std_naive).rename("upper")
lower_naive = (vwap_naive - std * exp_std_naive).rename("lower")

# put tz-aware index back

vwap  = vwap_naive.copy();  vwap.index  = px.index
upper = upper_naive.copy(); upper.index = px.index
lower = lower_naive.copy(); lower.index = px.index

sig = pd.concat([px[["open","high","low","close","volume"]], vwap, upper, lower], axis=1).dropna()

# %%
#Create state machine

long_entries   = pd.Series(False, index=sig.index)
short_entries  = pd.Series(False, index=sig.index)
long_exits     = pd.Series(False, index=sig.index)
short_exits    = pd.Series(False, index=sig.index)

in_pos   = False
side     = None
entry    = np.nan
entry_t  = None

#Lockouts to block repeated entries while staying above/below the band

can_long  = True   
can_short = True   

trades = []

# %%
#Trade logic

for t, row in sig.iterrows():
    o, h, l, c, vw, up, lo = row["open"], row["high"], row["low"], row["close"], row["vwap"], row["upper"], row["lower"]

    # --- reset conditions for lockouts (price back inside the band) ---
    # re-arm long entries once close >= lower band
    if not can_long and c >= lo:
        can_long = True
    # re-arm short entries once close <= upper band
    if not can_short and c <= up:
        can_short = True

    if not in_pos:
        # entry LONG: close < lower and long lockout open
        if can_long and (c < lo):
            in_pos = True; side = "long"; entry = c; entry_t = t
            long_entries.loc[t] = True
            can_long = False  # lock out further longs until reset
            continue
        # entry SHORT: close > upper and short lockout open
        if can_short and (c > up):
            in_pos = True; side = "short"; entry = c; entry_t = t
            short_entries.loc[t] = True
            can_short = False
            continue

    else:
        if side == "long":
            sl_hit = (l <= entry - sl)
            tp_hit = (vw > entry) and (h >= vw)
            if sl_hit:
                long_exits.loc[t] = True
                trades.append(dict(side="long", entry_time=entry_t, entry=entry,
                                   exit_time=t, exit=entry-sl, reason="SL",
                                   pnl=( -sl ) * no_of_shares))
                in_pos=False; side=None; entry=np.nan; entry_t=None
            elif tp_hit:
                long_exits.loc[t] = True
                trades.append(dict(side="long", entry_time=entry_t, entry=entry,
                                   exit_time=t, exit=vw, reason="VWAP",
                                   pnl=(vw-entry)*no_of_shares))
                in_pos=False; side=None; entry=np.nan; entry_t=None

        else:  # short
            sl_hit = (h >= entry + sl)
            tp_hit = (vw < entry) and (l <= vw)
            if sl_hit:
                short_exits.loc[t] = True
                trades.append(dict(side="short", entry_time=entry_t, entry=entry,
                                   exit_time=t, exit=entry+sl, reason="SL",
                                   pnl=( -sl ) * no_of_shares))
                in_pos=False; side=None; entry=np.nan; entry_t=None
            elif tp_hit:
                short_exits.loc[t] = True
                trades.append(dict(side="short", entry_time=entry_t, entry=entry,
                                   exit_time=t, exit=vw, reason="VWAP",
                                   pnl=(entry-vw)*no_of_shares))
                in_pos=False; side=None; entry=np.nan; entry_t=None

# %%
#Vectorbt backtest

pf = vbt.Portfolio.from_signals(
    close=sig["close"],
    entries=long_entries.values,
    exits=long_exits.values,
    short_entries=short_entries.values,
    short_exits=short_exits.values,
    init_cash=initial_equity,
    fees=0.0,
    slippage=0.0001,
    size=no_of_shares,
    allow_partial=False,
    freq="4H"
)
print(pf.stats())

#Save trades to CSV to check

pf.trades.records.to_csv("vbt_trades.csv", index=False)
print(f"Trades saved to vbt_trades.csv ({len(pf.trades.records)} rows)")

#Plot backtest equity curve

pf.plot()
# Out:
# Start                         2024-08-08 08:00:00-04:00
# End                           2025-08-07 20:00:00-04:00
# Period                                151 days 08:00:00
# Start Value                                    100000.0
# End Value                                   103164.2417
# Total Return [%]                               3.164242
# Benchmark Return [%]                          21.978466
# Max Gross Exposure [%]                       775.448637
# Total Fees Paid                                     0.0
# Max Drawdown [%]                               2.070515
# Max Drawdown Duration                  22 days 04:00:00
# Total Trades                                         26
# Total Closed Trades                                  26
# Total Open Trades                                     0
# Open Trade PnL                                      0.0
# Win Rate [%]                                  76.923077
# Best Trade [%]                                 1.568953
# Worst Trade [%]                               -3.240807
# Avg Winning Trade [%]                          0.463477
# Avg Losing Trade [%]                           -0.62819
# Avg Winning Trade Duration              1 days 01:36:00
# Avg Losing Trade Duration     3 days 01:19:59.999999999
# Profit Factor                                  2.383576
# Expectancy                                   121.701604
# Sharpe Ratio                                   1.502995
# Calmar Ratio                                   3.768643
# Omega Ratio                                    1.190748
# Sortino Ratio                                  2.388384
# Name: close, dtype: object
# Trades saved to vbt_trades.csv (26 rows)
# /Users/leondabrowski/Quanty Coding stuff/quantystuff/lib/python3.12/site-packages/vectorbt/utils/datetime_.py:24: FutureWarning:
#
# 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ceaa38c8-1d17-44c1-bf3e-9b731906b7e3',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x',
#               'y': array([519.19, 527.69, 531.77, ..., 631.79, 632.74, 633.3 ], shape=(908,)),
#               'yaxis': 'y'},
#              {'customdata': array([[  1., 100.,   0.],
#                                    [  3., 100.,   0.],
#                                    [  5., 100.,   0.],
#                                    [  6., 100.,   0.],
#                                    [  9., 100.,   0.],
#                                    [ 10., 100.,   0.],
#                                    [ 13., 100.,   0.],
#                                    [ 15., 100.,   0.],
#                                    [ 17., 100.,   0.],
#                                    [ 19., 100.,   0.],
#                                    [ 20., 100.,   0.],
#                                    [ 23., 100.,   0.],
#                                    [ 25., 100.,   0.],
#                                    [ 27., 100.,   0.],
#                                    [ 28., 100.,   0.],
#                                    [ 31., 100.,   0.],
#                                    [ 32., 100.,   0.],
#                                    [ 35., 100.,   0.],
#                                    [ 37., 100.,   0.],
#                                    [ 39., 100.,   0.],
#                                    [ 41., 100.,   0.],
#                                    [ 43., 100.,   0.],
#                                    [ 45., 100.,   0.],
#                                    [ 47., 100.,   0.],
#                                    [ 49., 100.,   0.],
#                                    [ 50., 100.,   0.]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': '7efafbcf-f9b6-4e86-a366-de3dffd3db43',
#               'x': array([datetime.datetime(2024, 8, 12, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 6, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 10, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 18, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 24, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 26, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 10, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 15, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 30, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 11, 12, 19, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 5, 15, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 12, 15, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 18, 15, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 1, 8, 19, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 2, 6, 11, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 3, 27, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 4, 23, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 6, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 21, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 29, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 30, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 6, 20, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 25, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 30, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 31, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 4, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([534.813476, 540.65406 , 544.244419, 561.296124, 571.147109, 574.437438,
#                           576.137608, 581.578152, 579.197914, 596.449639, 607.140708, 605.140508,
#                           596.609655, 588.568851, 604.710465, 568.15681 , 537.193714, 559.005895,
#                           583.078302, 592.839278, 588.448839, 595.289523, 636.983692, 636.103604,
#                           637.733767, 625.132507]),
#               'yaxis': 'y'},
#              {'customdata': array([[  0., 100.,   0.],
#                                    [  2., 100.,   0.],
#                                    [  4., 100.,   0.],
#                                    [  7., 100.,   0.],
#                                    [  8., 100.,   0.],
#                                    [ 11., 100.,   0.],
#                                    [ 12., 100.,   0.],
#                                    [ 14., 100.,   0.],
#                                    [ 16., 100.,   0.],
#                                    [ 18., 100.,   0.],
#                                    [ 21., 100.,   0.],
#                                    [ 22., 100.,   0.],
#                                    [ 24., 100.,   0.],
#                                    [ 26., 100.,   0.],
#                                    [ 29., 100.,   0.],
#                                    [ 30., 100.,   0.],
#                                    [ 33., 100.,   0.],
#                                    [ 34., 100.,   0.],
#                                    [ 36., 100.,   0.],
#                                    [ 38., 100.,   0.],
#                                    [ 40., 100.,   0.],
#                                    [ 42., 100.,   0.],
#                                    [ 44., 100.,   0.],
#                                    [ 46., 100.,   0.],
#                                    [ 48., 100.,   0.],
#                                    [ 51., 100.,   0.]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': 'e70172d7-b0ce-44c9-b4e2-9c42ed10352e',
#               'x': array([datetime.datetime(2024, 8, 12, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 15, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 10, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 18, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 24, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 9, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 10, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 15, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 30, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 11, 12, 15, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 6, 11, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 12, 11, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 18, 11, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 1, 8, 15, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 2, 6, 19, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 3, 27, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 4, 23, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 4, 30, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 21, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 28, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 30, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 6, 6, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 1, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 30, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 30, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 4, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([534.436551, 545.185476, 546.885306, 565.053489, 570.682926, 576.702324,
#                           577.022292, 584.281566, 582.9417  , 597.880206, 608.569137, 606.719322,
#                           606.119382, 588.791115, 605.489445, 568.633131, 535.24647 , 559.14408 ,
#                           589.941   , 596.54034 , 590.34096 , 595.250469, 616.988295, 636.056388,
#                           638.876106, 629.956998]),
#               'yaxis': 'y'},
#              {'customdata': array([[1.00000000e+00, 1.00000000e+00, 4.53141600e+02, 8.31169611e-03],
#                                    [2.00000000e+00, 2.00000000e+00, 2.64088700e+02, 4.82895951e-03],
#                                    [3.00000000e+00, 3.00000000e+00, 3.75736500e+02, 6.69408685e-03],
#                                    [5.00000000e+00, 5.00000000e+00, 2.26488600e+02, 3.94278968e-03],
#                                    [6.00000000e+00, 6.00000000e+00, 8.84684000e+01, 1.53318860e-03],
#                                    [7.00000000e+00, 7.00000000e+00, 2.70341400e+02, 4.62690278e-03],
#                                    [8.00000000e+00, 8.00000000e+00, 3.74378600e+02, 6.42223056e-03],
#                                    [9.00000000e+00, 9.00000000e+00, 1.43056700e+02, 2.39273183e-03],
#                                    [1.00000000e+01, 1.00000000e+01, 1.42842900e+02, 2.35271492e-03],
#                                    [1.10000000e+01, 1.10000000e+01, 1.57881400e+02, 2.60221480e-03],
#                                    [1.20000000e+01, 1.20000000e+01, 9.50972700e+02, 1.56895280e-02],
#                                    [1.30000000e+01, 1.30000000e+01, 2.22264000e+01, 3.77492109e-04],
#                                    [1.40000000e+01, 1.40000000e+01, 7.78980000e+01, 1.28818674e-03],
#                                    [1.50000000e+01, 1.50000000e+01, 4.76321000e+01, 8.37659598e-04],
#                                    [1.70000000e+01, 1.70000000e+01, 1.38185000e+01, 2.47136659e-04],
#                                    [1.80000000e+01, 1.80000000e+01, 6.86269800e+02, 1.16328548e-02],
#                                    [1.90000000e+01, 1.90000000e+01, 3.70106200e+02, 6.20421077e-03],
#                                    [2.00000000e+01, 2.00000000e+01, 1.89212100e+02, 3.20513251e-03],
#                                    [2.40000000e+01, 2.40000000e+01, 1.14233900e+02, 1.78804464e-03],
#                                    [2.50000000e+01, 2.50000000e+01, 4.82449100e+02, 7.71754939e-03]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': array([0.78824425, 0.77209178, 0.780742  , 0.76798185, 0.75680644, 0.77115467,
#                                            0.77948116, 0.76079288, 0.76060729, 0.76176444, 0.82246165, 0.75144647,
#                                            0.75567015, 0.75358067, 0.7508419 , 0.80364734, 0.77847002, 0.76456069,
#                                            0.75798843, 0.78548868]),
#                          'size': array([ 8.78473172,  8.03094988,  8.43462644,  7.83915279,  7.31763372,
#                                          7.98721798,  8.37578755,  7.50366791,  7.4950069 ,  7.5490071 ,
#                                         10.38154376,  7.06750196,  7.26460704,  7.16709775,  7.03928864,
#                                          9.50354265,  8.32860071,  7.67949886,  7.37279318,  8.6561383 ]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': 'f08b9156-d42f-41a3-8ac0-f6bfd22c1055',
#               'x': array([datetime.datetime(2024, 9, 6, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 10, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 18, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 9, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 10, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 15, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 10, 30, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 11, 12, 19, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 6, 11, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 12, 15, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2024, 12, 18, 15, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 1, 8, 19, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 2, 6, 19, 0, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>),
#                           datetime.datetime(2025, 3, 27, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 6, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 21, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 29, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 5, 30, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 31, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 4, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([0.0083117 , 0.00482896, 0.00669409, 0.00394279, 0.00153319, 0.0046269 ,
#                           0.00642223, 0.00239273, 0.00235271, 0.00260221, 0.01568953, 0.00037749,
#                           0.00128819, 0.00083766, 0.00024714, 0.01163285, 0.00620421, 0.00320513,
#                           0.00178804, 0.00771755]),
#               'yaxis': 'y2'},
#              {'customdata': array([[ 0.00000000e+00,  0.00000000e+00, -3.76925000e+01, -7.05275489e-04],
#                                    [ 4.00000000e+00,  4.00000000e+00, -4.64183000e+01, -8.13381615e-04],
#                                    [ 1.60000000e+01,  1.60000000e+01, -1.94724400e+02, -3.62484510e-03],
#                                    [ 2.10000000e+01,  2.10000000e+01, -3.90540000e+00, -6.56093561e-05],
#                                    [ 2.20000000e+01,  2.20000000e+01, -1.99953970e+03, -3.24080654e-02],
#                                    [ 2.30000000e+01,  2.30000000e+01, -4.72160000e+00, -7.42324122e-05]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '4',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': array([0.75296669, 0.75346807, 0.76650726, 0.75      , 0.9       , 0.75003999]),
#                          'size': array([ 7.13844536,  7.16184318,  7.77033884,  7.        , 14.        ,
#                                          7.00186632]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': 'a6aafec5-737d-4861-8381-9f46ea855262',
#               'x': array([datetime.datetime(2024, 8, 12, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 9, 24, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 4, 23, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 6, 20, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 25, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 7, 30, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([-7.05275489e-04, -8.13381615e-04, -3.62484510e-03, -6.56093561e-05,
#                           -3.24080654e-02, -7.42324122e-05]),
#               'yaxis': 'y2'},
#              {'legendgroup': '5',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '120fb4f4-3e86-485d-bd24-dc238622dd8b',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.01637166, 1.02423005, ..., 1.21687629, 1.21870606,
#                           1.21978466], shape=(908,)),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '51f56e2a-54f1-4cb6-a263-6739fb7e52e8',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1], shape=(908,)),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd55ef9f1-0a10-4d5a-a3f8-329abc3499bc',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.03164242, 1.03164242,
#                           1.03164242], shape=(908,)),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '557d16d2-3e57-4de4-a8aa-f5fca3358292',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1], shape=(908,)),
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '693439f5-f290-41f3-b01a-b623362144a0',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x3',
#               'y': array([1., 1., 1., ..., 1., 1., 1.], shape=(908,)),
#               'yaxis': 'y3'},
#              {'legendgroup': '7',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '72ce5177-ea7f-4ea2-952f-275a44b4547c',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x3',
#               'y': array([1.        , 1.        , 1.        , ..., 1.03164242, 1.03164242,
#                           1.03164242], shape=(908,)),
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '22639c0e-3e16-470e-bdca-d11220b01f8d',
#               'x': array([datetime.datetime(2024, 8, 8, 8, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2024, 8, 8, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           ...,
#                           datetime.datetime(2025, 8, 7, 12, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 16, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#                           datetime.datetime(2025, 8, 7, 20, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#                          shape=(908,), dtype=object),
#               'xaxis': 'x3',
#               'y': array([1, 1, 1, ..., 1, 1, 1], shape=(908,)),
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })

# %%
#Plot last x days to check visually if logic works
end_ts = sig.index.max()
start_ts = end_ts - pd.Timedelta(days=30)
win = sig.loc[start_ts:end_ts].copy()

candle = win[["open","high","low","close"]].copy()
candle.columns = ["Open","High","Low","Close"]
candle.index = candle.index.tz_localize(None)

trades_df = pd.DataFrame(trades)

def marker_series(times, prices, index):
    s = pd.Series(np.nan, index=index, dtype=float)
    if len(times)==0: return s
    tt = pd.to_datetime(times)
    if isinstance(tt, pd.Series):
        try:
            if getattr(tt.dt, "tz", None) is not None:
                tt = tt.dt.tz_localize(None)
        except AttributeError:
            tt = pd.to_datetime(tt)
    elif isinstance(tt, pd.DatetimeIndex) and tt.tz is not None:
        tt = tt.tz_localize(None)
    nearest = index.get_indexer(pd.DatetimeIndex(tt), method="nearest")
    p = pd.to_numeric(prices, errors="coerce")
    for i, j in enumerate(nearest):
        if 0 <= j < len(s): s.iloc[j] = float(p.iloc[i])
    return s

apds = [
    mpf.make_addplot(win["vwap"].tz_localize(None),  color="tab:orange"),
    mpf.make_addplot(win["upper"].tz_localize(None), color="tab:green"),
    mpf.make_addplot(win["lower"].tz_localize(None), color="tab:red"),
]

if not trades_df.empty:
    L = trades_df[trades_df["side"]=="long"]
    S = trades_df[trades_df["side"]=="short"]
    if not L.empty:
        apds.append(mpf.make_addplot(
            marker_series(L["entry_time"], L["entry"], candle.index),
            type="scatter", marker="^", markersize=70, color="g"))
    if not S.empty:
        apds.append(mpf.make_addplot(
            marker_series(S["entry_time"], S["entry"], candle.index),
            type="scatter", marker="v", markersize=70, color="r"))
    ex_vwap = trades_df[trades_df["reason"]=="VWAP"]
    ex_sl   = trades_df[trades_df["reason"]=="SL"]
    if not ex_vwap.empty:
        apds.append(mpf.make_addplot(
            marker_series(ex_vwap["exit_time"], ex_vwap["exit"], candle.index),
            type="scatter", marker="o", markersize=60, color="tab:blue"))
    if not ex_sl.empty:
        apds.append(mpf.make_addplot(
            marker_series(ex_sl["exit_time"], ex_sl["exit"], candle.index),
            type="scatter", marker="x", markersize=60, color="k"))

fig, axes = mpf.plot(
    candle, type="candle", addplot=apds, style="yahoo",
    title="SPY 4h — Candles, VWAP, ±2σ, Entries/Exits (Last 10 Days)",
    ylabel="Price ($)", volume=False, figratio=(12,6), tight_layout=True,
    returnfig=True
)
legend_handles = [
    mlines.Line2D([], [], color="tab:orange", label="VWAP", linewidth=2),
    mlines.Line2D([], [], color="tab:green",  label="+2σ Band", linewidth=2),
    mlines.Line2D([], [], color="tab:red",    label="-2σ Band", linewidth=2),
    mlines.Line2D([], [], color="g", marker="^", linestyle="None", markersize=8, label="Long Entry"),
    mlines.Line2D([], [], color="r", marker="v", linestyle="None", markersize=8, label="Short Entry"),
    mlines.Line2D([], [], color="tab:blue", marker="o", linestyle="None", markersize=6, label="Exit @ VWAP"),
    mlines.Line2D([], [], color="k", marker="x", linestyle="None", markersize=6, label="Exit @ Stop"),
    mpatches.Patch(facecolor='black', edgecolor='black', label='Candlestick (OHLC)'),
]
axes[0].legend(handles=legend_handles, loc="upper left", fontsize=9, frameon=True)
plt.show()
